# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathanpastas/inmersion_datos/blob/main/Alura_Latam__Inmersion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clase 1 : Inmersion de Datos

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 

inmuebles = pd.read_csv('/content/drive/MyDrive/inmersion_datos/inmuebles_bogota.csv')

inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
#MUESTRA EL NUMERO DE FILAS Y COLUMNAS DE LOS DATOS 
inmuebles.shape
# Out:
# (9520, 8)

# %%
#Indica los nombres de las columnas
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
#Asignacion de nombre de las columnas al dataframe
#se crea un diccionario con los valores a remplazar
columnas={'Baños':'Banos','Área':'Area'}

#se asigna las nuevas columnas al dataframe
inmuebles = inmuebles.rename(columns=columnas)

#se muestran registros aleatorios 
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 2806  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 7587         Casa                   Casa en venta en Engativa             3
# 8923  Apartamento            Apartamento en venta en Cedritos             1
# 589   Apartamento          Apartamento en venta en La Calleja             3
# 845   Apartamento            Apartamento en venta en Cedritos             3
# 7281  Apartamento           Apartamento en venta en Barrancas             3
# 6018  Apartamento             Apartamento en venta en Kennedy             3
# 8475         Casa         Casa en venta en Zona Noroccidental             5
# 2693  Apartamento            Apartamento en venta en Hayuelos             3
# 2735  Apartamento  Apartamento en venta en Zona Noroccidental             3
#
#       Banos  Area              Barrio                                    UPZ  \
# 2806      2   122  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 7587      3   120            Engativa                               Engativá
# 8923      1    45            Cedritos                                Usaquén
# 589       4   186          La Calleja  USAQUÉN: Country Club + Santa Bárbara
# 845       3   108            Cedritos                                Usaquén
# 7281      3    76           Barrancas                    San Cristóbal Norte
# 6018      1    42             Kennedy                        Kennedy Central
# 8475      2    61  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 2693      2    57            Hayuelos                                Modelia
# 2735      2    75  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
#
#               Valor
# 2806  $ 720.000.000
# 7587  $ 430.000.000
# 8923  $ 330.000.000
# 589   $ 970.000.000
# 845   $ 498.000.000
# 7281  $ 337.000.000
# 6018  $ 165.000.000
# 8475  $ 500.000.000
# 2693  $ 225.000.000
# 2735  $ 343.000.000

# %%
#Nos da una breve info del dataset 
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
#Localizar un indice dentro del dataset 

inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
#Localizar datatos a partir de un indice x hasta otro indice y dentro del dataset 
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
#Toma solo el valor del indice 300 del dataset

inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
#Toma solo los valores del indice 300 al 305 del dataset
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
#determina el tipo de dato del resultado

type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
#promedio del area de todos los inmuebles

inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
(inmuebles.Barrio=='Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
#cantidad de inmuebles que existen el barrio determinado
sum((inmuebles.Barrio=='Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio=='Chico Reservado')
inmuebles_chico
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
#Se crea un nuevo dataframe solo con los inmuebles del barrio chico reservado
chico_reservado=inmuebles[inmuebles_chico] #mascara que es un pandas series la cual contiene F o V (cuando se habla del barrio chico reservado)
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
#media del area del barrio chico reservado

chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
#determinar cuantos barrios se tiene el dataset 

len(inmuebles.Barrio.value_counts())
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
#determinar cuantas UPZ  se tiene el dataset 

inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
#grafico de cuantos barrios vs inmuebles

inmuebles_barrio=inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
#grafico de cuantos barrios vs inmuebles solomanete el top10

inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# 1. Promedio de area de todos los inmuebles en los barrios en el dataset. El top 10

# %%
barrio_area=inmuebles.loc[:,['Barrio','Area']]
promedio_barrios=barrio_area.groupby(by=["Barrio"]).mean()
promedio_barrios=promedio_barrios.sort_values(by='Area',ascending=False)
promedio_barrios
# Out:
#                         Area
# Barrio
# Modelia          4316.750000
# Libertador        642.000000
# Bosa Piamonte     400.000000
# La Soledad        378.625000
# Restrepo          336.500000
# ...                      ...
# La Merced          41.000000
# El Tunal           41.000000
# San Diego          40.666667
# La Macarena        37.000000
# Prado Veraniego    25.000000
#
# [149 rows x 1 columns]

# %%
promedio_barrios.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# ## **AULA 2**

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 3278  Apartamento     Apartamento en venta en Chico Reservado             3
# 4495  Apartamento        Apartamento en venta en San Patricio             3
# 7279  Apartamento             Apartamento en venta en Usaquén             3
# 1092  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8093         Casa                       Casa en venta en Suba             9
#
#       Banos  Area              Barrio                                    UPZ  \
# 3278      4   326     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 4495      5   180        San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 7279      2    61             Usaquén                                Usaquén
# 1092      2    90  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 8093      7   900                Suba                                   Suba
#
#                 Valor
# 3278  $ 3.900.000.000
# 4495    $ 885.000.000
# 7279    $ 257.000.000
# 1092    $ 460.000.000
# 8093    $ 948.000.000

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor=inmuebles.Valor.str.split(expand=True)

# %%
inmuebles['Moneda']=valor[0]
inmuebles['Precio']=valor[1]

# %%
inmuebles.sample(5)
# Out:
#              Tipo                        Descripcion  Habitaciones  Banos  \
# 8490  Apartamento   Apartamento en venta en Santa Fe             1      2
# 7227  Apartamento       Apartamento en venta en Bosa             3      2
# 9111  Apartamento   Apartamento en venta en Cedritos             3      3
# 2766  Apartamento   Apartamento en venta en Engativa             3      2
# 7934  Apartamento  Apartamento en venta en Chapinero             3      3
#
#       Area     Barrio                                     UPZ          Valor  \
# 8490    53   Santa Fe  SANTA FE: Las Nieves + Sagrado Corazón  $ 410.000.000
# 7227    47       Bosa                            Bosa Central  $ 126.000.000
# 9111   159   Cedritos                                 Usaquén  $ 879.000.000
# 2766    52   Engativa                                Engativá  $ 196.000.000
# 7934   100  Chapinero      CHAPINERO: Pardo Rubio + Chapinero  $ 590.000.000
#
#      Moneda       Precio
# 8490      $  410.000.000
# 7227      $  126.000.000
# 9111      $  879.000.000
# 2766      $  196.000.000
# 7934      $  590.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
#Eliminar el punto de la columna de precio 

inmuebles['Precio']=inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles.sample(5)
# Out:
#              Tipo                          Descripcion  Habitaciones  Banos  \
# 519   Apartamento      Apartamento en venta en Usaquén             3      2
# 178          Casa  Casa en venta en Zona Noroccidental             4      4
# 595          Casa             Casa en venta en Usaquén             2      3
# 2234         Casa      Casa en venta en Barrios Unidos             3      3
# 6791  Apartamento         Apartamento en venta en Bosa             3      1
#
#       Area              Barrio                                 UPZ  \
# 519     60             Usaquén                             Usaquén
# 178    220  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 595    158             Usaquén                             Usaquén
# 2234   116      Barrios Unidos                           Los Andes
# 6791    47                Bosa                        Bosa Central
#
#                 Valor Moneda      Precio
# 519     $ 230.000.000      $   230000000
# 178   $ 1.300.000.000      $  1300000000
# 595     $ 770.000.000      $   770000000
# 2234    $ 206.375.776      $   206375776
# 6791    $ 130.000.000      $   130000000

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles['Precio_Millon']=inmuebles.Precio.astype('float')/1000000
inmuebles.sample(5)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 6102  Apartamento  Apartamento en venta en Santa Barbara             3      4
# 3751         Casa    Casa en venta en Zona Noroccidental             4      5
# 4295         Casa    Casa en venta en Zona Noroccidental             8      4
# 2217  Apartamento  Apartamento en venta en Santa Barbara             3      3
# 5096  Apartamento        Apartamento en venta en Usaquén             3      4
#
#       Area              Barrio                                    UPZ  \
# 6102   180       Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 3751   680  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 4295   549  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 2217   165       Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 5096   270             Usaquén                                Usaquén
#
#                 Valor Moneda      Precio  Precio_Millon
# 6102    $ 720.000.000      $   720000000          720.0
# 3751  $ 4.000.000.000      $  4000000000         4000.0
# 4295  $ 1.350.000.000      $  1350000000         1350.0
# 2217    $ 590.000.000      $   590000000          590.0
# 5096  $ 2.250.000.000      $  2250000000         2250.0

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
#Configuracion de pandas el cual ajusta algunas posiciones decimales para que el dataset sea mas  entendible
pd.set_option('display.precision',2)
pd.set_option('display.float_format',lambda x: '%.2f' % x ) 
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
#Localiza un valor dentro del dataset que indica los datos que cumplan con esa condicion
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
#Localiza un valor dentro del dataset que indica los datos que cumplan con esa condicion
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
#Histograma : La frecuencia de una variable. Distribucion de frecuencias de una variable
inmuebles['Precio_Millon'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Preparar un lienzo para las posteriores graficas
#                   (ancho,altura)
plt.figure(figsize=(10,8))
grafica=sns.histplot(data=inmuebles,x='Precio_Millon',kde=True, hue='Tipo')
grafica.set_title('Distribución de valores de los Inmuebles en Bogotá')
#Limite maximo de la variables para entender mejor el gráfico de distribución
plt.xlim((50,1000))
#plt.ylim((0,20))
plt.savefig('/content/drive/MyDrive/inmersion_datos/valor_inmuebles.png',format='png')
plt.show()

# %% [markdown]
# **Desafios : **
#   1.  Seleccionar 2 o 3 tipos de (Apartamenos,Casas,Fincas) inmuebles.
#     Tamaños de label, titulos,aumentar el tamaño de labels, conclusion de la informacion
#
#     2. Precion del m2 por barrio (buscar una grafica mas adecuada para esta nueva variable. (Precio / m2 )
